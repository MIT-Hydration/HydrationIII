# %%
import pandas as pd
df1 = pd.read_csv("rig_1628724002.4456928.csv")

# %%
import matplotlib.pyplot as plt
import datetime as dt

# %matplotlib inline

plt.figure(figsize=[20, 10])
plt.subplots_adjust(bottom=0.2)
#plt.xticks( rotation=25 )
ax=plt.gca()
#xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
#ax.xaxis.set_major_formatter(xfmt)
#dates1=[dt.datetime.fromtimestamp(ts) for ts in df1["time_s"] ]
#dates2=[dt.datetime.fromtimestamp(ts) for ts in df2["time_s"] ]

plt.plot(df1["pos_0_m"], df1[" torque_0_Percent"])
plt.xlabel("z [m]")
plt.xlabel("Tz [percent]")
plt.ylim([-20, 10])

plt.show()

# %%
plt.figure(figsize=[20, 10])
plt.subplots_adjust(bottom=0.2)
#plt.xticks( rotation=25 )
ax=plt.gca()
#xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
#ax.xaxis.set_major_formatter(xfmt)
#dates1=[dt.datetime.fromtimestamp(ts) for ts in df1["time_s"] ]
#dates2=[dt.datetime.fromtimestamp(ts) for ts in df2["time_s"] ]

plt.plot(df1["pos_0_m"], df1[" torque_0_Percent"])
plt.xlim([-0.725, -0.6])
plt.ylim([-25, 250])
plt.show()

# %%
import matplotlib.dates as md
df_wob = pd.read_csv("WOB_1628722865.0995402.csv")
df_wob = df_wob[1:]

minIndex = 15000
maxIndex = -1


plt.figure(figsize=[20, 10])
plt.subplots_adjust(bottom=0.2)
plt.xticks( rotation=25 )
ax=plt.gca()
xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
ax.xaxis.set_major_formatter(xfmt)
dates1=[dt.datetime.fromtimestamp(ts) for ts in df_wob["time_s"] ]

plt.plot(dates1[minIndex:maxIndex], df_wob["wob_n"][minIndex:maxIndex])
#plt.ylim([-150, 50])
plt.show()
